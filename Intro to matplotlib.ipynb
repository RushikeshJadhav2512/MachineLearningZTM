# %% [markdown]
# #introduction to matplotlib

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %%
#1st method
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
fig=plt.figure()
ax=fig.add_axes([1,2,3,3])
ax.plot(x,y)
plt.show();

# %%
fig, ax=plt.subplots()
ax.plot(x,y);

# %% [markdown]
# #Matplotlib example workflow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x=[1,2,3,4]

y=[11,22,33,44]

fig,ax=plt.subplots(figsize=(10,10))

ax.plot(x,y)

ax.set(title="simple plot",
      xlabel="x-axis",
      ylabel="y-axis")

fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## making figure with numpy array

# %%
#create some data
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, ax=plt.subplots()
ax.plot(x,x**2);

# %%
#use same data for scatter plot
fig, ax=plt.subplots()
ax.scatter(x,np.exp(x));

# %%
fig, ax=plt.subplots()
ax.scatter(x,np.sin(x));

# %%
nut_butter_prices={"almond butter":34,
                  "peanut butter":42,
                  "cashew butter":345}
fig, ax=plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Rj's butter",
      ylabel="Price($)");

# %%
fig, ax=plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
x=np.random.randn(1000)

# %%
x
# Out:
# array([ 9.99668897e-01, -4.40887695e-01, -1.32126046e+00, -4.33804976e-01,
#         2.20531125e-01,  1.48608304e+00,  7.04093811e-01, -5.48361246e-01,
#        -1.25936506e-02, -8.29120645e-01, -9.18471686e-01, -1.61419340e+00,
#         8.04808791e-02,  1.72892353e+00,  1.12401254e-01,  3.11184787e-01,
#         1.28604971e+00,  9.92336178e-02,  1.79592515e+00,  1.61181994e+00,
#        -1.10837207e+00,  5.33328601e-01,  2.89150466e-01, -1.55244249e+00,
#        -5.90448249e-03, -3.91786170e-01,  1.66687046e-01,  2.67713113e+00,
#        -3.26002395e-02, -1.30380247e-01, -8.46851532e-01, -7.12451770e-01,
#        -2.16726128e+00,  1.02955438e+00, -5.58038721e-01, -1.11143826e-01,
#         1.18868566e+00, -1.17755129e+00, -7.72909513e-02, -3.59846750e-01,
#         4.22502649e-01,  2.64347500e+00, -7.96153383e-01, -1.17743642e-01,
#         1.57603634e+00,  1.08030142e+00, -3.32885406e-01,  2.07052476e-01,
# ...

# %%
x=np.random.randn(1000)
fig, ax=plt.subplots()
ax.hist(x);

# %% [markdown]
# ##two options for subplot

# %%
fig, ((ax1,ax2),(ax3,ax4))= plt.subplots(nrows=2,
                                        ncols=2,
                                        figsize=(10,5))
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
fig, ax=plt.subplots(nrows=2,
                    ncols=2,
                    figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %%
import numpy as np

# %%
import pandas as pd

# %%
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts=pd.Series(np.random.randn(1000),
            index=pd.date_range("1/1/2020",periods=1000))
ts=ts.cumsum()
ts.plot();

# %%
car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
# C:\Users\new\AppData\Local\Temp\ipykernel_13148\58638859.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]=car_sales["Price"].str.replace('[\$\,\.]','')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales["Price"]=car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale date"]=pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["total sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale date  total sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales.plot(x="Sale date",y="total sales")
# Out:
# <Axes: xlabel='Sale date'>

# %%
car_sales["Price"]=car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
x=np.random.rand(10,4)
x

df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.341487  0.896966  0.783850  0.452110
# 1  0.186985  0.754337  0.937085  0.667594
# 2  0.902201  0.201604  0.216901  0.115106
# 3  0.919153  0.753069  0.925794  0.221604
# 4  0.250422  0.232455  0.872189  0.236537
# 5  0.191424  0.841866  0.113961  0.453767
# 6  0.190162  0.518746  0.692684  0.260966
# 7  0.595806  0.327126  0.815726  0.988085
# 8  0.582917  0.340144  0.535336  0.305388
# 9  0.191032  0.524508  0.068734  0.046788

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales.plot(x="Make",y="Odometer (KM)", kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
heart_disease=pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %%
Over_50=heart_disease[heart_disease["age"]>50]
Over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot
Over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target');

# %%
#oo method
fix, ax=plt.subplots(figsize=(10,6))
Over_50.plot(kind='scatter',
           x='age',
            y='chol',
            c='target',
             ax=ax);

#ax.set_xlim([45,100])

# %%
#oo method from scratch
fig, ax=plt.subplots(figsize=(10,6))

scatter=ax.scatter(x=Over_50["age"],
                  y=Over_50["chol"],
                  c=Over_50["target"])

ax.set(title="Heatsr disease and cholesterol levels",
      xlabel="Age",
      ylabel="Cholesterol");

ax.legend(*scatter.legend_elements(), title="target");

ax.axhline(Over_50["chol"].mean(),
                 linestyle="--" );

# %%
#subplot of chol,age,thalach

fig, (ax0,ax1)=plt.subplots(nrows=2,
                           ncols=1,
                           figsize=(10,10),
                           sharex=True)

scatter=ax0.scatter(x=Over_50["age"],
                   y=Over_50["chol"],
                  c=Over_50["target"])

ax0.set(title="Hearts disease and cholesterol levels",
      
      ylabel="Cholesterol");

ax0.legend(*scatter.legend_elements(), title="target");

ax0.axhline(Over_50["chol"].mean(),
                 linestyle="--" );


scatter=ax1.scatter(x=Over_50["age"],
                   y=Over_50["thalach"],
                  c=Over_50["target"])

ax1.set(title="Hearts disease and Max heart rate",
      xlabel="Age",
      ylabel="Max heart rate");

ax1.legend(*scatter.legend_elements(), title="target");

ax1.axhline(Over_50["thalach"].mean(),
                 linestyle="--" );

fig.suptitle("Heat Disease analysis", fontsize=16,fontweight="bold");

# %% [markdown]
# ##customizing Matplotlob and getting stylish

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\new\AppData\Local\Temp\ipykernel_13148\2414357448.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')
# Out:
# C:\Users\new\AppData\Local\Temp\ipykernel_13148\240305066.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
x=np.random.randn(10,4)
x
# Out:
# array([[-0.7213503 , -0.83896949, -0.08743546,  0.15283347],
#        [-0.64341897, -0.70858263, -0.59159191, -0.91443213],
#        [-0.34494727, -0.02865408,  0.61422975, -0.47463313],
#        [-0.0581777 ,  0.72882854, -0.49028756,  2.73230628],
#        [ 0.15419008,  0.07994069, -1.03577085, -0.71548352],
#        [-1.85997287,  0.76516008,  0.72388314, -0.2549974 ],
#        [ 0.60835042, -0.42431388,  0.343017  ,  0.44518733],
#        [ 1.28146363,  0.17168112, -0.76272861,  1.20943289],
#        [ 0.15527877, -1.9537112 ,  0.9209382 ,  0.55749465],
#        [-0.38425458,  1.37936437, -0.57885405, -1.09377202]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.721350 -0.838969 -0.087435  0.152833
# 1 -0.643419 -0.708583 -0.591592 -0.914432
# 2 -0.344947 -0.028654  0.614230 -0.474633
# 3 -0.058178  0.728829 -0.490288  2.732306
# 4  0.154190  0.079941 -1.035771 -0.715484
# 5 -1.859973  0.765160  0.723883 -0.254997
# 6  0.608350 -0.424314  0.343017  0.445187
# 7  1.281464  0.171681 -0.762729  1.209433
# 8  0.155279 -1.953711  0.920938  0.557495
# 9 -0.384255  1.379364 -0.578854 -1.093772

# %%
ax=df.plot(kind='bar')

# %%
ax=df.plot(kind="bar")
ax.set(title="Random no. bar graph from dataframe",
      xlabel="Row no.",
      ylabel="Random number")
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-whitegrid')


fig, ax=plt.subplots(figsize=(10,6))

scatter=ax.scatter(x=Over_50["age"],
                  y=Over_50["chol"],
                  c=Over_50["target"],
                  cmap="winter")

ax.set(title="Heatsr disease and cholesterol levels",
      xlabel="Age",
      ylabel="Cholesterol");

ax.legend(*scatter.legend_elements(), title="target");

ax.axhline(Over_50["chol"].mean(),
                 linestyle="--" );
# Out:
# C:\Users\new\AppData\Local\Temp\ipykernel_13148\2268081053.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
#subplot of chol,age,thalach

fig, (ax0,ax1)=plt.subplots(nrows=2,
                           ncols=1,
                           figsize=(10,10),
                           sharex=True)

scatter=ax0.scatter(x=Over_50["age"],
                   y=Over_50["chol"],
                  c=Over_50["target"],
                   cmap='winter')

ax0.set(title="Hearts disease and cholesterol levels",
      
      ylabel="Cholesterol");
ax0.set_xlim([50,80])

ax0.legend(*scatter.legend_elements(), title="target");

ax0.axhline(Over_50["chol"].mean(),
                 linestyle="--" );


scatter=ax1.scatter(x=Over_50["age"],
                   y=Over_50["thalach"],
                  c=Over_50["target"],
                   cmap='winter')

ax1.set(title="Hearts disease and Max heart rate",
      xlabel="Age",
      ylabel="Max heart rate");


ax1.set_xlim([50,80])
ax1.set_ylim([60,200])


ax1.legend(*scatter.legend_elements(), title="target");

ax1.axhline(Over_50["thalach"].mean(),
                 linestyle="--" );

fig.suptitle("Heat Disease analysis", fontsize=16,fontweight="bold");

# %%
fig.savefig('heart dieases coding.png')
